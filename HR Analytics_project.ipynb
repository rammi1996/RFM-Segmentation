# %%
import pandas as pd 
df=pd.read_csv(r"D:\data\Downloads\archive (4)\HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
# Detection of outliers 
num_cols=[]
for c in  df.columns:
    if df[c].dtypes=='int64':
        if len(df[c].unique())>5:
            num_cols.append(c)

plt.figure(figsize=(16,10))
for i,col in enumerate(num_cols):
    axes = plt.subplot(5,4, i + 1)
    sns.boxplot(x=df[col])
plt.tight_layout()
plt.show()

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
num_df=df.select_dtypes(include=int)
num_df.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
cat_df=df.select_dtypes(include=object)
cat_df.head()
# Out:
#   Attrition     BusinessTravel              Department EducationField  Gender  \
# 0       Yes      Travel_Rarely                   Sales  Life Sciences  Female
# 1        No  Travel_Frequently  Research & Development  Life Sciences    Male
# 2       Yes      Travel_Rarely  Research & Development          Other    Male
# 3        No  Travel_Frequently  Research & Development  Life Sciences  Female
# 4        No      Travel_Rarely  Research & Development        Medical    Male
#
#                  JobRole MaritalStatus Over18 OverTime
# 0        Sales Executive        Single      Y      Yes
# 1     Research Scientist       Married      Y       No
# 2  Laboratory Technician        Single      Y      Yes
# 3     Research Scientist       Married      Y      Yes
# 4  Laboratory Technician       Married      Y       No

# %%
import math

total_subplots = 26  # Total number of numerical columns
desired_columns = 2   # Desired number of columns in the subplot grid

# Calculate number of rows and columns for subplot grid
nrows = math.ceil(total_subplots / desired_columns)
ncols = math.ceil(total_subplots / nrows)

print("Number of Rows:", nrows)
print("Number of Columns:", ncols)
# Out:
# Number of Rows: 13
# Number of Columns: 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
numerical_cols = df.select_dtypes(include='number').columns
descriptive_stats = df[numerical_cols].describe()

fig, axes = plt.subplots(nrows=13, ncols=2, figsize=(5, 8))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i, col in enumerate(numerical_cols):
    sns.histplot(df[col], kde=True, ax=axes[i//2, i%2])
    axes[i//2, i%2].set_title(f'Distribution of {col}', fontsize=8)
    axes[i//2, i%2].set_xlabel("")
    axes[i//2, i%2].set_ylabel("")

plt.show()

print(descriptive_stats)
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

sns.set_style("whitegrid")
categorical_columns=df.select_dtypes(exclude='number').columns # we have 9 categoricalcolumns
fig,axes=plt.subplots(nrows=9,ncols=2,figsize=(4,8))
fig.subplots_adjust(hspace=0.4,wspace=0.4)

for i, col in enumerate(categorical_columns):
    sns.countplot(data=df,x=col,ax=axes[i//2,i%2])
    axes[i//2, i%2].set_title(f'Distribution of {col}', fontsize=8)
    axes[i//2, i%2].set_xlabel("")
    axes[i//2, i%2].set_ylabel("")
    axes[i//2,i%2].tick_params(axis='x',rotation=45)
    

plt.show()

# %%
# Univariate Analysis Based on Age

import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure(figsize=(10,6))
sns.histplot(x='Age',data=df,kde=True)
plt.xlabel('Age')
plt.show()

# %%
# Univariate Analysis Based on Hourly Rate

import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure(figsize=(10,6))
sns.histplot(x='HourlyRate',data=df,kde=True)
plt.xlabel('EmpHourRate')
plt.show()

# %%
# Univariate Analysis Based on TotalWorking Years

import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure(figsize=(10,6))
sns.histplot(x='TotalWorkingYears',data=df,kde=True)
plt.xlabel('EmpExperience')
plt.show()

# %%
# DAta preprocessing and visulaizing 
df.Attrition.value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
gender=pd.crosstab(df["Gender"],df["Attrition"])
gender
# Out:
# Attrition   No  Yes
# Gender
# Female     501   87
# Male       732  150

# %%
df.Department.value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
department=pd.crosstab(df["Department"],df["Attrition"])
department
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
# Data preprocessing 

df.BusinessTravel.value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
Business=pd.crosstab(df["Attrition"],df["BusinessTravel"])
Business
# Out:
# BusinessTravel  Non-Travel  Travel_Frequently  Travel_Rarely
# Attrition
# No                     138                208            887
# Yes                     12                 69            156

# %%
df.EducationField.value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
education_field=pd.crosstab(df["EducationField"],df["Attrition"])
education_field
# Out:
# Attrition          No  Yes
# EducationField
# Human Resources    20    7
# Life Sciences     517   89
# Marketing         124   35
# Medical           401   63
# Other              71   11
# Technical Degree  100   32

# %%
df.JobRole.value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
job_role=pd.crosstab(df["JobRole"],df["Attrition"])
job_role
# Out:
# Attrition                   No  Yes
# JobRole
# Healthcare Representative  122    9
# Human Resources             40   12
# Laboratory Technician      197   62
# Manager                     97    5
# Manufacturing Director     135   10
# Research Director           78    2
# Research Scientist         245   47
# Sales Executive            269   57
# Sales Representative        50   33

# %%
# DAta preprocessing and visulaizing 
df.MaritalStatus.value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
Marital_status=pd.crosstab(df["MaritalStatus"],df["Attrition"])
Marital_status
# Out:
# Attrition       No  Yes
# MaritalStatus
# Divorced       294   33
# Married        589   84
# Single         350  120

# %%
df.EnvironmentSatisfaction.value_counts()
# Out:
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: count, dtype: int64

# %%
df.JobRole.value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
Jobrole=pd.crosstab(df["JobRole"],df["Attrition"])
Jobrole
# Out:
# Attrition                   No  Yes
# JobRole
# Healthcare Representative  122    9
# Human Resources             40   12
# Laboratory Technician      197   62
# Manager                     97    5
# Manufacturing Director     135   10
# Research Director           78    2
# Research Scientist         245   47
# Sales Executive            269   57
# Sales Representative        50   33

# %%
df.OverTime.value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
overtime=pd.crosstab(df["OverTime"],df["Attrition"])
overtime
# Out:
# Attrition   No  Yes
# OverTime
# No         944  110
# Yes        289  127

# %%
import seaborn as sns 
numeric_df=df.select_dtypes('number')
plt.figure(figsize=(9,9))
sns.heatmap(numeric_df.corr(),annot=True,fmt='.1f')
# Out:
# <Axes: >

# %%
# As it clearly see correlation among these columns in the above heat map 
correlation2 = df[['Age','JobLevel','MonthlyIncome','NumCompaniesWorked','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']].corr()
plt.figure(figsize=(12,10))
sns.heatmap(correlation2,fmt='.2f',annot=True)
plt.xticks(rotation=40)
plt.show()

# %%
# Data preprocessing
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df,x='Attrition' , hue='Attrition')

plt.title('Attrition')
plt.xlabel('Attrition Count')
plt.ylabel('Count')
plt.show()

# %%
# Attrition based on Gender

import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='Gender', hue='Attrition')

plt.title('Attrition by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

attrition_yes=df[df["Attrition"]=="Yes"]
attrition_no=df[df["Attrition"]=="No"]


sns.histplot(data=attrition_yes,x="Age",color='red',alpha=0.5, label='Attrition: Yes')
sns.histplot(data=attrition_no,x="Age",color='pink',alpha=0.5,label='Attrition:No')
# Add labels and title
plt.title("Distribution of Age based on Attrition")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.legend()

# Show the plot
plt.show()

# %%
# attrition based on martial Status 

import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='MaritalStatus', hue='Attrition')

plt.title('Attrition by MaritalStatus')
plt.xlabel('Departments')
plt.ylabel('Count')
plt.show()

# %%
# attrition based on jobrole
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='JobRole', hue='Attrition')

plt.title('Attrition Based on JobRole')
plt.xticks(rotation=30)
plt.xlabel('JobRole')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

sns.countplot(data=df,x="BusinessTravel",hue="Attrition")
plt.title("Attrition Based on BusinessTravel")
plt.xlabel("BusineesTravel")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df,x="Department",hue="Attrition")
plt.title("Attrition Based on Department")
plt.xlabel("Department")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt



# Plotting
plt.figure(figsize=(10, 6))
sns.countplot(data=df,  x='JobSatisfaction', hue='Attrition')
plt.title('Count of Employees by Job Satisfaction and Attrition')
plt.xlabel('Count')
plt.ylabel('Job Satisfaction')
plt.legend(title='Attrition')
plt.grid(axis='x')
plt.show()

# %%
# To calculate the attrition rate we need to convert into numeric value
df1=df.replace({'Attrition':{'Yes':1,'No':0}})
df1.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# KPI based on Attrition Rate

# calculate the attrition rate 

import matplotlib.pyplot as plt

#Total_Employee = number_left + number_retained

number_left=df[df['Attrition']=='Yes'].shape[0]
number_retained=df[df['Attrition']=='No'].shape[0]


Total_Employee = number_left + number_retained


#Attrition_Rate= (number_left/number_retained)*100
Attrition_Rate = (number_left / Total_Employee) * 100

labels=['Left','Retained']
sizes=[number_left,number_retained]

plt.figure(figsize=(10,8))
plt.pie(sizes,labels=labels,autopct='%1.1f%%', startangle=140)
plt.title('Attrition Rate Based on Retention')

# Adding legends with exact values
plt.legend(loc='upper right', labels=[f'{label}: {size}%' for label, size in zip(labels, sizes)])

plt.show()

print("Attrition Rate: {:.2f}%".format(Attrition_rate))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 29
#      25 plt.legend(loc='upper right', labels=[f'{label}: {size}%' for label, size in zip(labels, sizes)])
#      27 plt.show()
# ---> 29 print("Attrition Rate: {:.2f}%".format(Attrition_rate))
#
# NameError: name 'Attrition_rate' is not defined

# %%
# KPI 2 based on Attrition Rate on Gender

import pandas as pd

# Assuming 'df' is your DataFrame containing the data

# Calculate attrition rate for each gender
attrition_by_gender = df1.groupby('Gender')['Attrition'].count()

# Convert attrition rate to percentage
attrition_percentage = attrition_by_gender * 100

print("Attrition Rate by Gender:")
print(attrition_percentage)


# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(attrition_percentage, labels=attrition_percentage.index, autopct='%1.1f%%', startangle=140)
plt.title('Attrition Rate by Gender')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()
# Out:
# Attrition Rate by Gender:
# Gender
# Female    58800
# Male      88200
# Name: Attrition, dtype: int64

# %%
# KPI 3 based on Marital Status

import matplotlib.pyplot as plt

married_attrition = df1[df1["MaritalStatus"] == "Married"]["Attrition"]
single_attrition = df1[df1["MaritalStatus"] == "Single"]["Attrition"]
divorced_attrition = df1[df1["MaritalStatus"] == "Divorced"]["Attrition"]

fig, axes = plt.subplots(ncols=3, nrows=1, figsize=(18, 6))

married_attrition.value_counts().plot(kind='pie', autopct='%.2f', ax=axes[0], title='Married Attrition')
single_attrition.value_counts().plot(kind='pie', autopct='%.2f', ax=axes[1], title="Single Attrition")
divorced_attrition.value_counts().plot(kind='pie', autopct='%.2f', ax=axes[2], title="Divorced Attrition")

plt.show()

# %%
# KPI 4 based on Department Attrition 

import pandas as pd

# Assuming 'df' is your DataFrame containing the data

# Calculate attrition rate for each gender
attrition_by_Department = df1.groupby('Department')['Attrition'].count()

# Convert attrition rate to percentage
attrition_percentage = attrition_by_Department * 100

print("Attrition Rate by Department:")
print(attrition_percentage)


# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(attrition_percentage, labels=attrition_percentage.index, autopct='%.2f', startangle=140)
plt.title('Attrition Rate by Department')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()
# Out:
# Attrition Rate by Department:
# Department
# Human Resources            6300
# Research & Development    96100
# Sales                     44600
# Name: Attrition, dtype: int64

# %%
# Visualize distributions and relationships to identify factors associated with long-term success with in organization

import seaborn as sns
import matplotlib.pyplot as plt


# Define feature Categories 

job_related_features = ['JobLevel', 'DailyRate','DistanceFromHome']
experience_skills_features =['TotalWorkingYears','NumCompaniesWorked','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion']
work_environment_features = ['WorkLifeBalance', 'JobSatisfaction', 'EnvironmentSatisfaction']
performance_history_features = ['PerformanceRating', 'PercentSalaryHike','MonthlyIncome']

# Visualize distributions and relationships for each feature category
feature_categories = [demographic_features, job_related_features, experience_skills_features,
                      work_environment_features, performance_history_features]

for category in feature_categories:
    sns.pairplot(df[category+ ['Attrition']], hue='Attrition', diag_kind='kde')
    plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %%
# Filter numeric columns for correlation analysis
numeric_columns = df1.select_dtypes(include=['number']).columns

# Correlation Analysis for each numeric feature category
for category in feature_categories:
    category_columns = [col for col in numeric_columns if col in category]
    
    # Add 'Attrition' column for correlation analysis
    category_columns.append('Attrition')
    
    # Compute correlation matrix for the current category
    correlation_matrix_category = df1[category_columns].corr()
    
    # Plot correlation matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(correlation_matrix_category, annot=True, cmap='coolwarm')
    plt.title(f'Correlation Matrix for {category}')
    plt.show()

# %%
# distribution of attrition among employees based on age

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


age_bins=[20,30,40,50,60]

df1['Age_groups']=pd.cut(df1['Age'],bins=age_bins)

attrition_age_groups=df1.groupby(['Age_groups','Attrition']).size().reset_index(name='count')
# Plot the graph
plt.figure(figsize=(8, 6))
sns.barplot(data=attrition_age_groups, x='Age_groups', y='count',hue='Attrition')
plt.title('Attrition by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# job satisfaction vary across different  departments



import seaborn as sns
import matplotlib.pyplot as plt

data_subset = df1[['Department', 'JobSatisfaction', 'Attrition']]

# Visualize the mean job satisfaction across departments, considering attrition
plt.figure(figsize=(10, 8))
sns.barplot(x='Department', y='JobSatisfaction', hue='Attrition', data=data_subset, linewidth=0)
plt.title('Job Satisfaction across Department')
plt.xlabel('Department')
plt.ylabel('Mean Job Satisfaction')
plt.xticks(rotation=45)
plt.legend(title='Attrition')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## job satisfaction vary across different  JobRoles
import seaborn as sns
import matplotlib.pyplot as plt

# Create the stacked bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='JobRole', y='JobSatisfaction', hue='Attrition', data=data_subset, ci=None, estimator=sum)
plt.title('Distribution of Job Satisfaction Across Job Roles')
plt.xlabel('Job Role')
plt.ylabel('Job Satisfaction')
plt.xticks(rotation=45)
plt.legend(title='Attrition')
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12568\1179005589.py:6: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %%
# Calculate attrition count for each year of service
attrition_count = df1.groupby('YearsAtCompany')['Attrition'].sum().reset_index()

# Plotting the line chart
plt.figure(figsize=(10, 6))
sns.lineplot(data=attrition_count, x='YearsAtCompany', y='Attrition')
plt.title('Attrition Count by Years of Service')
plt.xlabel('Years of Service')
plt.ylabel('Attrition Count')
plt.show()

# %%
# correlation between commute distance and employee satisfaction
import seaborn as sns
import matplotlib.pyplot as plt

data_merged=df1.groupby(['DistanceFromHome','JobSatisfaction','Attrition']).size().reset_index(name='count')
# Scatter plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='DistanceFromHome', y='JobSatisfaction', data=data_merged)
plt.title('Scatter Plot of Commute Distance vs. Employee Satisfaction')
plt.xlabel('Commute Distance')
plt.ylabel('Employee Satisfaction')
plt.show()

# Calculate correlation coefficient
correlation = df['DistanceFromHome'].corr(df['JobSatisfaction'])
print(f"Correlation coefficient between Commute Distance and Employee Satisfaction: {correlation}")
# Out:
# Correlation coefficient between Commute Distance and Employee Satisfaction: -0.003668839167720459

# %%
# Montly income differ among employees with varying levels of education


import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'Education' represents the levels of education, 'MonthlyIncome' represents the monthly income,
# and 'Attrition' represents the attrition status
education_levels = merged['Education']
monthly_income = merged['MonthlyIncome']
attrition = merged['Attrition']

# Calculate the total monthly income for each education level and attrition status
income_by_education_attrition = merged.groupby(['Education', 'Attrition'])['MonthlyIncome'].sum().unstack()

# Plot the stacked bar chart
plt.figure(figsize=(10, 8))
income_by_education_attrition.plot(kind='bar', stacked=True)
plt.title('Total Monthly Income by Education Level and Attrition Status')
plt.xlabel('Education Level')
plt.ylabel('Total Monthly Income')
plt.xticks(ticks=[0, 1, 2, 3, 4], labels=['Below College', 'College', 'Bachelor', 'Master', 'Doctor'])
plt.legend(title='Attrition', labels=['No', 'Yes'])
plt.show()

# %%
# visulaize relationship between overtime and attrition rate 
import seaborn as sns
import matplotlib.pyplot as plt

# Create a count plot
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='OverTime', hue='Attrition')
plt.title('Attrition Rates by Overtime Work')
plt.xlabel('Overtime Work')
plt.ylabel('Count')
plt.show()

# Calculate overtime rate
overtime_rate = (df['OverTime'].value_counts(normalize=True) * 100)['Yes']

print(f"Overtime Rate: {overtime_rate:.2f}%")
# Out:
# Overtime Rate: 28.30%

# %%
# The relationship between performance ratings, job involvement, and employee retention
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='PerformanceRating', y='JobInvolvement', hue='Attrition', palette=['lightblue', 'lightcoral'])
plt.title('Relationship between Performance Rating, Job Involvement, and Employee Retention')
plt.xlabel('Performance Rating')
plt.ylabel('Job Involvement')
plt.legend(title='Attrition')
plt.show()

# %%
#  worklifeBalance in company based on attrition
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate attrition count for each year of service
attrition_count = df1.groupby('WorkLifeBalance')['Attrition'].sum().reset_index()

# Plotting the line chart
plt.figure(figsize=(10, 6))
sns.lineplot(data=attrition_count, x='WorkLifeBalance', y='Attrition')
plt.title('Attrition Count by Work Life Balance')
plt.xlabel('WorkLifeBalance')
plt.ylabel('Attrition Count')
plt.show()

# %%
#  Job Invovlvement in company based on attrition
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate attrition count for each year of service
attrition_count = df1.groupby('JobInvolvement')['Attrition'].sum().reset_index()

# Plotting the line chart
plt.figure(figsize=(10, 6))
sns.lineplot(data=attrition_count, x='JobInvolvement', y='Attrition')
plt.title('Attrition Count by Job Involvement')
plt.xlabel('JobInvolvement')
plt.ylabel('Attrition Count')
plt.show()

# %%
##  PercentSalaryHike in company based on attrition
# Calculate attrition count for each year of service
attrition_count = df1.groupby('PercentSalaryHike')['Attrition'].sum().reset_index()

# Plotting the line chart
plt.figure(figsize=(10, 6))
sns.lineplot(data=attrition_count, x='PercentSalaryHike', y='Attrition')
plt.title('Attrition Count by Percent Salary Hike')
plt.xlabel('PercentSalaryHike')
plt.ylabel('Attrition Count')
plt.show()


plt.figure(figsize=(10, 6))
sns.barplot(data=attrition_count, x='PercentSalaryHike', y='Attrition')
plt.title('Attrition Count by Percent Salary Hike')
plt.xlabel('Percent Salary Hike')
plt.ylabel('Attrition Count')
plt.show()

# %%
# Define the bin edges for monthly salary 
# Define the bin edges
bin_edges = list(range(0, 20001, 3000))

# Define the bin labels
bin_labels = [f'{i+1}-{i+3000}' for i in range(0, 18000, 3000)]

# Create the new variable MonthlyIncomeCat using pd.cut()
df2 = df1.copy()
df2['MonthlyIncomeCat'] = pd.cut(df1['MonthlyIncome'], bins=bin_edges, labels=bin_labels, include_lowest=True)

# Display the first few rows of df2
df2
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# visulaize the monthly salary based on attrition
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate attrition count for each year of service
attrition_count = df2.groupby('MonthlyIncomeCat')['Attrition'].mean().reset_index()

# Plotting the line chart
plt.figure(figsize=(10, 6))
sns.lineplot(data=attrition_count, x='MonthlyIncomeCat', y='Attrition')
plt.title('Attrition Count by Monthly Income Category')
plt.xlabel('Monthly Income Categorye')
plt.ylabel('Attrition Count')
plt.show()

# %%
# Relationship between monthly income and Job Role Based on gender
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting the box plot
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='JobRole', y='MonthlyIncome', hue='Gender', palette='Set2')
plt.title('Monthly Income by Job Role and Gender')
plt.xlabel('Job Role')
plt.ylabel('Monthly Income')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# Print the result
average_income_gender = df.groupby('Gender')['MonthlyIncome'].mean()

print("Average Monthly Income Based on Gender:")
print(average_income_gender)
# Out:
# Average Monthly Income Based on Gender:
# Gender
# Female    6686.566327
# Male      6380.507937
# Name: MonthlyIncome, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'Education' represents the levels of education, 'MonthlyIncome' represents the monthly income,
# and 'Attrition' represents the attrition status
education_levels = df1['Education']
monthly_income = df1['MonthlyIncome']
attrition = df1['Attrition']

# Create a DataFrame from education, monthly income, and attrition
data = pd.DataFrame({'Education': education_levels, 'Monthly Income': monthly_income, 'Attrition': attrition})

# Create a boxplot to visualize the distribution of monthly income across different education levels, considering attrition
plt.figure(figsize=(10, 8))
sns.boxplot(x='Education', y='Monthly Income', hue='Attrition', data=data)
plt.title('Monthly Income Across Education Levels by Attrition Status')
plt.xlabel('Education Level')
plt.ylabel('Monthly Income')
plt.xticks(ticks=[0, 1, 2, 3, 4], labels=['Below College', 'College', 'Bachelor', 'Master', 'Doctor'])
plt.legend(title='Attrition', loc='upper right')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df1[['Attrition', 'WorkLifeBalance','YearsSinceLastPromotion','DistanceFromHome','MonthlyIncome' ]].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Between Performance Ratings, Job Involvement, and Employee Retention')
plt.show()

# %%
# Box plot of MonthlyIncome by Attrition
plt.figure(figsize=(10, 8))
sns.boxplot(x='Attrition', y='NumCompaniesWorked', data=df1)
plt.title('Distribution of Number of Companies Worked by Attrition Status')
plt.xlabel('Attrition')
plt.ylabel('Number of Companies Worked')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'])
plt.show()

# %%
# Violin plot of YearsSinceLastPromotion by Attrition
plt.figure(figsize=(10, 8))
sns.violinplot(x='Attrition', y='YearsSinceLastPromotion', data=df1)
plt.title('Distribution of Years Since Last Promotion by Attrition Status')
plt.xlabel('Attrition')
plt.ylabel('Years Since Last Promotion')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'])
plt.show()
